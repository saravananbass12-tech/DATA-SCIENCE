# %%
import numpy as np
a=np.array([1,2,3,4,5])
print(np.argmax(a))
# Out:
# 4

# %%
print(np.argmin(a))
# Out:
# 0

# %%
print(np.where(a>3))
# Out:
# (array([3, 4]),)

# %%
print(np.cumsum(a))
# Out:
# [ 1  3  6 10 15]

# %%
r=np.random.randint(1,20,1)
print(r)
# Out:
# [5]

# %%
r=np.random.randint(1,20,5)
print(r)
# Out:
# [ 3  2  9 13 16]

# %%
r=np.random.randint(1,20,20)
print(r)
# Out:
# [17 18  2  4 17 17 18 12  2  1  5 15 12 12  9  4 19  6 12 17]

# %%
a=np.array([1,2,3,4,5,6])
b=np.array([3,4,5,6,8,9])
print(np.corrcoef(a,b))
# Out:
# [[1.         0.99216093]
#  [0.99216093 1.        ]]

# %%
a=np.array([100,99,98,97,96,95])
np.save("ps.npy",a)
print(np.load("ps.npy"))
# Out:
# [100  99  98  97  96  95]

# %%
a=np.array([1,2,3,4,5])
print(a[2:])
# Out:
# [3 4 5]

# %%
a=np.array([1,2,3,4,5])
print(a[0:-3])
# Out:
# [1 2]

# %%
a=np.array([1,2,3,4,5])
print(a[:-1])
# Out:
# [1 2 3 4]

# %%
import pandas as sa

# %%
z=sa.read_csv("programming_languages.csv")
z
# Out:
#      language  difficulty  popularity                             use_cases  \
# 0      Python           1        57.9     AI; Data Science; Web Development
# 1  JavaScript           2        62.3  Web Development; Front-end; Back-end
# 2        Java           3        30.0          Enterprise; Android; Backend
# 3         C++           5        23.5   Game Development; Systems; Embedded
# 4          C#           3        27.0        Game Development; Desktop; Web
#
#    year_created         paradigm   typing
# 0          1991   Multi-paradigm  Dynamic
# 1          1995   Multi-paradigm  Dynamic
# 2          1995  Object-oriented   Static
# 3          1985   Multi-paradigm   Static
# 4          2000  Object-oriented   Static

# %%
x=z.loc[1:3,"language":"typing"]
x
# Out:
#      language  difficulty  popularity                             use_cases  \
# 1  JavaScript           2        62.3  Web Development; Front-end; Back-end
# 2        Java           3        30.0          Enterprise; Android; Backend
# 3         C++           5        23.5   Game Development; Systems; Embedded
#
#    year_created         paradigm   typing
# 1          1995   Multi-paradigm  Dynamic
# 2          1995  Object-oriented   Static
# 3          1985   Multi-paradigm   Static

# %%
x=z.loc[1:3,"language":"year_created"]
x
# Out:
#      language  difficulty  popularity                             use_cases  \
# 1  JavaScript           2        62.3  Web Development; Front-end; Back-end
# 2        Java           3        30.0          Enterprise; Android; Backend
# 3         C++           5        23.5   Game Development; Systems; Embedded
#
#    year_created
# 1          1995
# 2          1995
# 3          1985
