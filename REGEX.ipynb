# %%
import re

# %%
text="this is my email saravananbass12@gmail.com"
a=re.findall(r'\w{2,}+@\w{2,}\.\w{2,}',text)
a
# Out:
# ['saravananbass12@gmail.com']

# %%
print(text[0:17])
# Out:
# this is my email

# %%
text=input("enter the text:")
a=a=re.findall(r'\w{2,}+@\w{2,}\.\w{2,}',text)
a
# Out:
# enter the text:my email saro123@gmail.com
# ['saro123@gmail.com']

# %%
text=input("enter the text:")
a=re.findall(r'@',text)
if a:
  print("fount")
else:
  print("not fount")
a
# Out:
# enter the text:saro@gmail.com
# fount
# ['@']

# %%
text=input("enter the text:")
a=re.search(r'@',text)
if a:
  print("fount")
else:
  print("not fount")
a
# Out:
# enter the text:my email sar@gmail.com
# fount
# <re.Match object; span=(12, 13), match='@'>

# %%
text ="I AM LEARNING DATA SCIENCE"
a=re.sub(r'DATA SCIENCE','JAVA',text)
a
# Out:
# 'I AM LEARNING JAVA'

# %%
text=input("enter the email:")
a=re.fullmatch(r'\w+@\W+\.\w+',text)
if a:
  print("valid email")

else:
  print("invalid")
# Out:
# enter the email:saro#gmail
# invalid

# %%
text="my phone number is 8610277272"
a=re.search(r'\d{10}',text)
a
# Out:
# <re.Match object; span=(19, 29), match='8610277272'>
